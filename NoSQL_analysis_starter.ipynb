# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
collections = db.list_collection_names()
pprint(collections)
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# let's pprint the first document to investigate the key-value pairs
first_entry = establishments.find_one()
pprint(first_entry)
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65765f36f21d885e59961576'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = [item for item in establishments.find({"scores.Hygiene":20})]
pprint(query[:2])   #this line will print only the first 2 entries for purpose of brevity

# Use count_documents to display the number of documents in the result
count_documents = establishments.count_documents({"scores.Hygiene":20})
print(f"The number of establishments with hygiene score of 20 is {count_documents}.")

# Display the first document in the results using pprint
establishments.find_one({"scores.Hygiene":20})
# Out:
# [{'AddressLine1': '5-6 Southfields Road',
#   'AddressLine2': 'Eastbourne',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'BusinessName': 'The Chase Rest Home',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4613.888288172291,
#   'FHRSID': 110681,
#   'LocalAuthorityBusinessID': '4029',
#   'LocalAuthorityCode': '102',
#   'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#   'LocalAuthorityName': 'Eastbourne',
#   'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN21 1BU',
#   'RatingDate': '2021-09-23T00:00:00',
#   'RatingKey': 'fhrs_0_en-gb',
#   'RatingValue': 0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f36f21d885e599630a7'),
#   'geocode': {'latitude': Decimal128('50.769705'),
#               'longitude': Decimal128('0.27694')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}},
#  {'AddressLine1': 'Hall Lane',
#   'AddressLine2': 'Walton-on-the-Naze',
#   'AddressLine3': 'Essex',
#   'AddressLine4': '',
#   'BusinessName': 'Brenalwood',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4617.965823673803,
#   'FHRSID': 612039,
#   'LocalAuthorityBusinessID': '1970/FOOD',
#   'LocalAuthorityCode': '120',
#   'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#   'LocalAuthorityName': 'Tendring',
#   'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CO14 8HN',
#   'RatingDate': '2022-06-22T00:00:00',
#   'RatingKey': 'fhrs_0_en-gb',
#   'RatingValue': 0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f36f21d885e5996342b'),
#   'geocode': {'latitude': Decimal128('51.857536'),
#               'longitude': Decimal128('1.278721')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/612039',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}]
# The number of establishments with hygiene score of 20 is 41.
# {'_id': ObjectId('65765f36f21d885e599630a7'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': Decimal128('0.27694'),
#   'latitude': Decimal128('50.769705')},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/110681'}]}

# %%
import pandas as pd
# Convert the result to a Pandas DataFrame
estab20_df = pd.DataFrame(query)


# Display the number of rows in the DataFrame
print(f"The number of rows in the DataFrame is equal to {len(estab20_df)}")

# Display the first 10 rows of the DataFrame
estab20_df.head(10)
# Out:
# The number of rows in the DataFrame is equal to 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  65765f36f21d885e599630a7   110681                  0
# 1  65765f36f21d885e5996342b   612039                  0
# 2  65765f36f21d885e59963733   730933                  0
# 3  65765f36f21d885e59963923   172735                  0
# 4  65765f36f21d885e5996392f   172953                  0
# 5  65765f37f21d885e599642d2   512854                  0
# 6  65765f37f21d885e599644f2  1537089                  0
# 7  65765f37f21d885e59965a17   155648                  0
# 8  65765f37f21d885e59965e71  1012883                  0
# 9  65765f37f21d885e59966670   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query_gte = [item for item in establishments.find({"RatingValue":{"$gte":4}})]
pprint(query_gte[:2])   #This line will pprint the first 2 entries in the `query_gte` list

# Use count_documents to display the number of documents in the result
count_documents_gte = establishments.count_documents({"RatingValue":{"$gte":4}})
print(f"The number of documents with the `RatingValue` greater than or equal to 4 is {count_documents_gte}")

# Display the first document in the results using pprint
establishments.find_one({"RatingValue":{"$gte":4}})
# Out:
# [{'AddressLine1': 'East Cliff Pavilion',
#   'AddressLine2': 'Wear Bay Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'The Pavilion',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4591.765489457773,
#   'FHRSID': 1043695,
#   'LocalAuthorityBusinessID': 'PI/000073616',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6BL',
#   'RatingDate': '2018-04-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f36f21d885e59961576'),
#   'geocode': {'latitude': Decimal128('51.083812'),
#               'longitude': Decimal128('1.195625')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Wear Bay Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Wear Bay Bowls Club',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4591.821311183521,
#   'FHRSID': 647177,
#   'LocalAuthorityBusinessID': 'PI/000041489',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6PY',
#   'RatingDate': '2014-03-31T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f36f21d885e59961577'),
#   'geocode': {'latitude': Decimal128('51.086058'),
#               'longitude': Decimal128('1.196408')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}]
# The number of documents with the `RatingValue` greater than or equal to 4 is 31257
# {'_id': ObjectId('65765f36f21d885e59961576'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': Decimal128('1.195625'),
#   'latitude': Decimal128('51.083812')},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %%
# Convert the result to a Pandas DataFrame
query_gte_df = pd.DataFrame(query_gte)

# Display the number of rows in the DataFrame
print(f"The number of rows in the DataFrame is equal to {len(query_gte_df)}")

# Display the first 10 rows of the DataFrame
query_gte_df.head(10)
# Out:
# The number of rows in the DataFrame is equal to 31257
#                         _id   FHRSID  ChangesByServerID  \
# 0  65765f36f21d885e59961576  1043695                  0
# 1  65765f36f21d885e59961577   647177                  0
# 2  65765f36f21d885e59961578   289353                  0
# 3  65765f36f21d885e5996157b   289352                  0
# 4  65765f36f21d885e5996157c   987206                  0
# 5  65765f36f21d885e5996157d   289560                  0
# 6  65765f36f21d885e5996157e   344689                  0
# 7  65765f36f21d885e59961580   894592                  0
# 8  65765f36f21d885e59961581  1043701                  0
# 9  65765f36f21d885e59961583   805702                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000073616                         The Pavilion
# 1             PI/000041489                  Wear Bay Bowls Club
# 2             PI/000002468  St Marys COE (aided) Primary School
# 3             PI/000002460                             The Ship
# 4             PI/000075655                     The Ships Galley
# 5             PI/000039927                              Mariner
# 6             PI/000002095             Folkestone Trawlers Shop
# 7             PI/000074396                               Docker
# 8             PI/000076360                      Pick Up Pintxos
# 9             PI/000073219             Dr Legumes - Harbour Arm
#
#                 BusinessType  BusinessTypeID  \
# 0    Restaurant/Cafe/Canteen               1
# 1          Pub/bar/nightclub            7843
# 2  School/college/university            7845
# 3          Pub/bar/nightclub            7843
# 4          Pub/bar/nightclub            7843
# 5          Pub/bar/nightclub            7843
# 6          Retailers - other            4613
# 7          Retailers - other            4613
# 8     Takeaway/sandwich shop            7844
# 9    Restaurant/Cafe/Canteen               1
#
#                                 AddressLine1           AddressLine2  \
# 0                        East Cliff Pavilion          Wear Bay Road
# 1                              Wear Bay Road             Folkestone
# 2  St Marys Church Of England Primary School            Warren Road
# 3                               23 The Stade             Folkestone
# 4                                   The Ship           23 The Stade
# 5                               16 The Stade             Folkestone
# 6                                1 The Stade             Folkestone
# 7                         Folkestone Harbour  Harbour Approach Road
# 8                         Folkestone Harbour  Harbour Approach Road
# 9                         Folkestone Harbour  Harbour Approach Road
#
#   AddressLine3  ...               LocalAuthorityWebSite  \
# 0   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 1         Kent  ...  http://www.folkestone-hythe.gov.uk
# 2   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 3         Kent  ...  http://www.folkestone-hythe.gov.uk
# 4   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 5         Kent  ...  http://www.folkestone-hythe.gov.uk
# 6         Kent  ...  http://www.folkestone-hythe.gov.uk
# 7   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 8   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 9   Folkestone  ...  http://www.folkestone-hythe.gov.uk
#
#          LocalAuthorityEmailAddress  \
# 0  foodteam@folkestone-hythe.gov.uk
# 1  foodteam@folkestone-hythe.gov.uk
# 2  foodteam@folkestone-hythe.gov.uk
# 3  foodteam@folkestone-hythe.gov.uk
# 4  foodteam@folkestone-hythe.gov.uk
# 5  foodteam@folkestone-hythe.gov.uk
# 6  foodteam@folkestone-hythe.gov.uk
# 7  foodteam@folkestone-hythe.gov.uk
# 8  foodteam@folkestone-hythe.gov.uk
# 9  foodteam@folkestone-hythe.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 1.195625, 'latitude': 51.083812}
# 1     {'longitude': 1.196408, 'latitude': 51.086058}
# 2     {'longitude': 1.194762, 'latitude': 51.085797}
# 3      {'longitude': 1.188537, 'latitude': 51.08084}
# 4      {'longitude': 1.188537, 'latitude': 51.08084}
# 5      {'longitude': 1.188537, 'latitude': 51.08084}
# 6      {'longitude': 1.188537, 'latitude': 51.08084}
# 7  {'longitude': 1.18590330311705, 'latitude': 51...
# 8  {'longitude': 1.18590330311705, 'latitude': 51...
# 9  {'longitude': 1.18590330311705, 'latitude': 51...
#
#       Distance NewRatingPending  \
# 0  4591.765489            False
# 1  4591.821311            False
# 2  4591.871474            False
# 3  4591.912145            False
# 4  4591.912145            False
# 5  4591.912145            False
# 6  4591.912145            False
# 7  4591.914705            False
# 8  4591.914705            False
# 9  4591.914705            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
import pymongo

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

search_filter = {
    "RatingValue":5,
    "geocode.latitude": {"$gte": 51.480142, "$lte": 51.500142},
    "geocode.longitude": {"$gte": 0.07384000, "$lte": 0.9384000}
}

query = [item for item in establishments.find(search_filter).sort("scores.Hygiene", pymongo.ASCENDING)]

# Print the results
pprint(query[:5])    #Let's print only 5 records for sake of brevity.
# Out:
# [{'AddressLine1': '7 Stanford House',
#   'AddressLine2': 'Princess Margaret Road',
#   'AddressLine3': 'East Tilbury',
#   'AddressLine4': 'Essex',
#   'BusinessName': "Nancy's Sandwich Bar",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4634.858686758785,
#   'FHRSID': 390400,
#   'LocalAuthorityBusinessID': '09/00040/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM18 8YP',
#   'RatingDate': '2022-05-23T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f37f21d885e599660a8'),
#   'geocode': {'latitude': Decimal128('51.480638'),
#               'longitude': Decimal128('0.417821')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/390400',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': '21 Southend Road',
#   'AddressLine2': 'Grays',
#   'AddressLine3': 'Essex',
#   'AddressLine4': '',
#   'BusinessName': 'Macchiatos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4637.945045824783,
#   'FHRSID': 1385053,
#   'LocalAuthorityBusinessID': '21/00149/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM17 5NH',
#   'RatingDate': '2022-08-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f37f21d885e5996693f'),
#   'geocode': {'latitude': Decimal128('51.4837954'),
#               'longitude': Decimal128('0.3361583')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1385053',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': 'The Oak',
#   'AddressLine2': 'Lodge Lane',
#   'AddressLine3': 'Grays',
#   'AddressLine4': 'Essex',
#   'BusinessName': 'The Oak At Sockets Heath',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4638.029750999956,
#   'FHRSID': 390727,
#   'LocalAuthorityBusinessID': '15410/2003/2/000',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM17 5RZ',
#   'RatingDate': '2022-07-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f37f21d885e59966955'),
#   'geocode': {'latitude': Decimal128('51.488892'),
#               'longitude': Decimal128('0.338999')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/390727',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': 'Unit 2 The Boardwalk',
#   'AddressLine2': 'Intu Lakeside',
#   'AddressLine3': 'West Thurrock Way',
#   'AddressLine4': 'West Thurrock',
#   'BusinessName': 'Bourgee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4640.067429127063,
#   'FHRSID': 1400430,
#   'LocalAuthorityBusinessID': '21/00171/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM20 2ZN',
#   'RatingDate': '2022-06-30T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f37f21d885e59966d6f'),
#   'geocode': {'latitude': Decimal128('51.487302'),
#               'longitude': Decimal128('0.281385')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1400430',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': '34 High Street',
#   'AddressLine2': 'Aveley',
#   'AddressLine3': 'South Ockendon',
#   'AddressLine4': 'Essex',
#   'BusinessName': 'Essex Chef',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4641.3552683351045,
#   'FHRSID': 1502433,
#   'LocalAuthorityBusinessID': '22/00112/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM15 4AD',
#   'RatingDate': '2022-07-19T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65765f37f21d885e59967101'),
#   'geocode': {'latitude': Decimal128('51.4985144'),
#               'longitude': Decimal128('0.257348')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1502433',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}}]

# %%
# Convert result to Pandas DataFrame
query_df = pd.DataFrame(query)
query_df.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65765f37f21d885e599660a8   390400                  0
# 1  65765f37f21d885e5996693f  1385053                  0
# 2  65765f37f21d885e59966955   390727                  0
# 3  65765f37f21d885e59966d6f  1400430                  0
# 4  65765f37f21d885e59967101  1502433                  0
#
#   LocalAuthorityBusinessID              BusinessName             BusinessType  \
# 0              09/00040/CP      Nancy's Sandwich Bar  Restaurant/Cafe/Canteen
# 1              21/00149/CP                Macchiatos  Restaurant/Cafe/Canteen
# 2         15410/2003/2/000  The Oak At Sockets Heath        Pub/bar/nightclub
# 3              21/00171/CP                   Bourgee  Restaurant/Cafe/Canteen
# 4              22/00112/CP                Essex Chef   Takeaway/sandwich shop
#
#    BusinessTypeID          AddressLine1            AddressLine2  \
# 0               1      7 Stanford House  Princess Margaret Road
# 1               1      21 Southend Road                   Grays
# 2            7843               The Oak              Lodge Lane
# 3               1  Unit 2 The Boardwalk           Intu Lakeside
# 4            7844        34 High Street                  Aveley
#
#         AddressLine3  ...            LocalAuthorityWebSite  \
# 0       East Tilbury  ...  http://www.thurrock.gov.uk/food
# 1              Essex  ...  http://www.thurrock.gov.uk/food
# 2              Grays  ...  http://www.thurrock.gov.uk/food
# 3  West Thurrock Way  ...  http://www.thurrock.gov.uk/food
# 4     South Ockendon  ...  http://www.thurrock.gov.uk/food
#
#    LocalAuthorityEmailAddress  \
# 0  foodsafety@thurrock.gov.uk
# 1  foodsafety@thurrock.gov.uk
# 2  foodsafety@thurrock.gov.uk
# 3  foodsafety@thurrock.gov.uk
# 4  foodsafety@thurrock.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 1  {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 2  {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 3  {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 4  {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
#
#                                             geocode RightToReply     Distance  \
# 0    {'longitude': 0.417821, 'latitude': 51.480638}               4634.858687
# 1  {'longitude': 0.3361583, 'latitude': 51.4837954}               4637.945046
# 2    {'longitude': 0.338999, 'latitude': 51.488892}               4638.029751
# 3    {'longitude': 0.281385, 'latitude': 51.487302}               4640.067429
# 4   {'longitude': 0.257348, 'latitude': 51.4985144}               4641.355268
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
hygiene_match = {"$match": {"scores.Hygiene": 0}}

# 2. Groups the matches by Local Authority
match_local_authority = {"$group": {"_id": "$LocalAuthorityName"}}

# 3. Sorts the matches from highest to lowest
sort_stage = {"$sort": {"count": -1}}

# result = [item for item in establishments.aggregate([hygiene_match, match_local_authority])]
result = [item for item in establishments.aggregate([hygiene_match, match_local_authority, sort_stage])]


# Print the number of documents in the result
print(f"Number of documents in the result: {len(result)}")

# Print the first 10 results
print(f"The first 10 results in the list are: {result[:10]}")
# Out:
# Number of documents in the result: 55
# The first 10 results in the list are: [{'_id': 'Basildon'}, {'_id': 'Babergh'}, {'_id': 'Chelmsford'}, {'_id': 'Tendring'}, {'_id': 'Eastbourne'}, {'_id': 'Tonbridge and Malling'}, {'_id': 'Tandridge'}, {'_id': 'Havering'}, {'_id': 'Greenwich'}, {'_id': 'Tunbridge Wells'}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print(f"The number of rows is {len(result_df)}")

# Display the first 10 rows of the DataFrame
# result_df.head(10)

# Let's rename the column accordingly and display the first 10 rows
renamed_df = result_df.rename(columns={"_id":"LocalAuthorityName"})
renamed_df.head(10)
# Out:
# The number of rows is 55
#       LocalAuthorityName
# 0               Basildon
# 1                Babergh
# 2             Chelmsford
# 3               Tendring
# 4             Eastbourne
# 5  Tonbridge and Malling
# 6              Tandridge
# 7               Havering
# 8              Greenwich
# 9        Tunbridge Wells

# %%
# *** END OF CODE ***
