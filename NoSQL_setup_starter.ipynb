# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
db_list = mongo.list_database_names()

# Print all database names and check if uk_food is in the list
for db_name in db_list:
    print(db_name)
# Out:
# admin
# autosaurus
# classDB
# class_DB
# config
# epa
# local
# travel_db
# uk_food

# %%
# assign the uk_food database to a variable name
# db = mongo['uk_food']   
db = mongo.uk_food
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food')

# %%
# review the collections in our new database
collections = db.list_collection_names()

# Print the names of the collections
for collection_name in collections:
    print(collection_name)
# Out:
# establishments

# %%
# review a document in the establishments collection
document = db.establishments.find_one()
print(document)
# Out:
# {'_id': ObjectId('657410aaa40086c457e9635b'), 'FHRSID': 254719, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000069980', 'BusinessName': 'Refreshment Kiosk', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'The Bay', 'AddressLine2': 'St Margarets Bay', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT15 6DY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-03-24T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Dover', 'LocalAuthorityWebSite': 'http://www.dover.gov.uk/', 'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.387974', 'latitude': '51.152225'}, 'RightToReply': '', 'Distance': 4587.347174863443, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
result = establishments.insert_one(penang_flavours)

# Let's check the ID of the new restaurant inside the collection.
print("Inserted document with ID:", result.inserted_id)
# Out:
# Inserted document with ID: 6574b84b4e3724f4b86a72b6

# %%
# Check that the new restaurant was inserted
new_restaurant = establishments.find_one({"BusinessName": "Penang Flavours"})
print(new_restaurant)
# Out:
# {'_id': ObjectId('6574b84b4e3724f4b86a72b6'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %%
#Let's import `bson` module
from bson import ObjectId

# %%
# Let's also check for the id
new_restaurant_by_id = establishments.find_one({"_id":ObjectId('6574b84b4e3724f4b86a72b6')})
new_restaurant_by_id
# Out:
# {'_id': ObjectId('6574b84b4e3724f4b86a72b6'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
result_BusinessTypeID = establishments.find({"BusinessType":"Restaurant/Cafe/Canteen"}, {"BusinessTypeID":1, "BusinessType":1})
result_BusinessTypeID
for result in result_BusinessTypeID:
    print(result)
# Out:
# {'_id': ObjectId('657410aaa40086c457e9635b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9635c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9635f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96360'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96361'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96363'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96364'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96366'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96369'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9636b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9636c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96370'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9637b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9637c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9637f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96389'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9638b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9638d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9638e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96390'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96393'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96398'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96399'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9639b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9639d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9639e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963a1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963a8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963aa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963ab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963b2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963b3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963be'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963c0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963c7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963c8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963cb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963d3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963e5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963ed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963f1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963f7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e963ff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96404'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96405'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96408'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96409'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9640a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96416'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96419'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9641d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9641f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96425'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96426'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96427'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9642c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96430'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96433'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96436'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96443'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96445'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96446'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96447'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96454'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96455'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96456'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96458'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96464'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9646d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9646e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96473'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96479'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9647a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96481'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96488'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9648f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96490'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96495'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96496'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96497'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9649a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9649d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964a0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964a5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964a7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964aa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964ab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964bf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964c0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964d4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964d5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964d8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964db'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964e4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964e5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e964fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96500'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96502'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96505'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96508'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96509'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96511'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9651c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9651d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9651e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96523'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96526'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96529'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9652b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9652f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96535'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9653d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9654b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96559'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96573'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9657c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9657d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96582'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96585'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96589'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96596'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965a8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965c1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965d1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965d3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965d5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965e5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965f4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e965fd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96600'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96602'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96606'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96607'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9660c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9660f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96610'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96617'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9661e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96623'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96625'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96634'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96636'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96638'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9663a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96640'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9664d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96650'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96653'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96661'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96663'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9666a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9666e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96673'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96674'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96676'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96685'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96689'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9668e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96690'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96695'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96699'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9669c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9669e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966a5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966ad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966b1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966b2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966bb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966c9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966cc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966d5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966d7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966e2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966e4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966ed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966f0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966fa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e966fd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96707'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96708'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9670a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9670d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96713'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96714'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96716'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9671b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96723'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96724'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96726'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96728'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96729'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9672a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9672d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96730'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96731'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96732'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96734'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96738'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96739'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9673c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96747'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96748'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9674b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96752'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96753'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96755'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96757'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96758'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96759'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9675a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9675c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9675f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96763'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96766'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96767'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9676b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96776'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96779'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96790'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96794'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96796'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9679a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9679b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9679f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967b8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967bf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967c2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967c4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967c8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967d5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967d7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967d8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967f8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967fa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967fd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e967ff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96802'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96803'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96804'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96806'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96808'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96809'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9680c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96816'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96818'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96819'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9681a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9681b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9681c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96820'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9682b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9682c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9682e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9682f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96832'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96833'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96834'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9683e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96844'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96848'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9684d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9684e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9684f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96851'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96852'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96856'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96861'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96863'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96866'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9686f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96872'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96874'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96878'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9687b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9687e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96882'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96887'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9688b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9688f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96890'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96891'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96894'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9689a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968a0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968a7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968aa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968ad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968b2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968b6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968b8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968bb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968be'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968c1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968c2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968c4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968c8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968c9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968cb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968cc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968d0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968d1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968d4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968d5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968d8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968e2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968e4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968f0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968f1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968f7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e968fd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96904'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96907'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96916'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96923'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96924'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9692a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9692e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96930'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96932'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9693d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96940'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96947'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96948'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9694a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9694f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96950'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96951'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96955'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96958'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9695e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9696a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9696c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9696e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96971'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96978'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9697b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9697c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96985'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96989'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9698d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e96993'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aaa40086c457e9699a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'_id': ObjectId('657410aba40086c457e9fca8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fca9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcaa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcb3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcb4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcb5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcb9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcbb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcbd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcc1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fccc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fccd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcd2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcd3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcd4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcd6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcd7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcd8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcd9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcde'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcdf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fce0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fce2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fce4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fce6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fce7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fce8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fce9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcef'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcf4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcf6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcf7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcf8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcf9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcfa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcfc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fcff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd0c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd0f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd1b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd1f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd21'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd25'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd26'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd40'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd58'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd5c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd61'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd63'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd6a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd6b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd6c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd6d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd6f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd8d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd8f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd94'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fd96'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fda4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fda8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdb0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdb1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdb3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdb4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdc3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdc8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fddb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fddd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fde1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fde4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fde6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fde7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdf7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdf8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdfa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdfc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fdff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe01'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe06'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe0c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe0e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe11'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe14'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe1d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe1e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe1f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe25'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe26'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe2b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe2c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe2d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe34'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe36'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe3a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe3b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe3c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe3f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe40'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe46'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe49'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe5b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe62'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe67'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe68'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe6f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe81'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe88'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe8b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe9e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fe9f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fea1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9fea5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9feaa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9feb2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('657410aba40086c457e9feb8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6574b84b4e3724f4b86a72b6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': ''}

# %%
# Let's display what BusinessName and BusinessTypeID from the previous result
result_BusinessName = establishments.find({"BusinessType":"Restaurant/Cafe/Canteen"}, {"_id":0, "BusinessName":1, "BusinessTypeID":1, })
result_BusinessName
for result in result_BusinessName:
    print(result)
# Out:
# {'BusinessName': 'Refreshment Kiosk', 'BusinessTypeID': 1}
# {'BusinessName': 'The Tea Room', 'BusinessTypeID': 1}
# {'BusinessName': 'FirstLight Bar & Café', 'BusinessTypeID': 1}
# {'BusinessName': 'The Halfway Hut', 'BusinessTypeID': 1}
# {'BusinessName': 'Lovetocater', 'BusinessTypeID': 1}
# {'BusinessName': 'Mrs Knotts Tea Room', 'BusinessTypeID': 1}
# {'BusinessName': 'The Barn', 'BusinessTypeID': 1}
# {'BusinessName': 'The White Cliffs', 'BusinessTypeID': 1}
# {'BusinessName': 'Boodles', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lounge Bar', 'BusinessTypeID': 1}
# {'BusinessName': "St Margaret's Bowls and Social Club", 'BusinessTypeID': 1}
# {'BusinessName': 'Boat House & Langdon', 'BusinessTypeID': 1}
# {'BusinessName': 'National Trust White Cliffs', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Burger King', 'BusinessTypeID': 1}
# {'BusinessName': 'Walmer Castle Tea Rooms', 'BusinessTypeID': 1}
# {'BusinessName': 'Table Table at Premier Inn', 'BusinessTypeID': 1}
# {'BusinessName': 'Food Outlets', 'BusinessTypeID': 1}
# {'BusinessName': 'GCP Catering Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Places Leisure', 'BusinessTypeID': 1}
# {'BusinessName': 'The Dover Patrol Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'The Pedaler on the Port', 'BusinessTypeID': 1}
# {'BusinessName': 'Port of Dover Cargo Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Cullins Yard', 'BusinessTypeID': 1}
# {'BusinessName': 'Dover Marina Hotel', 'BusinessTypeID': 1}
# {'BusinessName': "Wheeler's Fish & Chips", 'BusinessTypeID': 1}
# {'BusinessName': "Mr White's English Chophouse (DMHS)", 'BusinessTypeID': 1}
# {'BusinessName': 'Boardwalk Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Kaspas', 'BusinessTypeID': 1}
# {'BusinessName': 'Marks and Spencer Dover Simply Food', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee, Next', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Nandos', 'BusinessTypeID': 1}
# {'BusinessName': 'Taco Bell', 'BusinessTypeID': 1}
# {'BusinessName': 'Rico Sabor', 'BusinessTypeID': 1}
# {'BusinessName': 'Cinnamon Island', 'BusinessTypeID': 1}
# {'BusinessName': 'German Doner Kebab', 'BusinessTypeID': 1}
# {'BusinessName': 'IL RUSTICO', 'BusinessTypeID': 1}
# {'BusinessName': 'Aspendos', 'BusinessTypeID': 1}
# {'BusinessName': 'Blakes of Dover', 'BusinessTypeID': 1}
# {'BusinessName': 'Terrace Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Dinos Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC', 'BusinessTypeID': 1}
# {'BusinessName': 'Xpresso Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Sunrise Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Bluebirds', 'BusinessTypeID': 1}
# {'BusinessName': 'Happy Chef', 'BusinessTypeID': 1}
# {'BusinessName': 'THENU Convenience Store', 'BusinessTypeID': 1}
# {'BusinessName': 'Chaplins', 'BusinessTypeID': 1}
# {'BusinessName': 'Pizza Shack', 'BusinessTypeID': 1}
# {'BusinessName': 'The Market Square Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Vinoteq Wine Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Honey Pot Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'La Salle Verte', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Melange', 'BusinessTypeID': 1}
# {'BusinessName': 'The Shake Shop & The Hot Dog Hut', 'BusinessTypeID': 1}
# {'BusinessName': 'The Corner Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'MFG ESSO WALMER', 'BusinessTypeID': 1}
# {'BusinessName': 'Tummy Station', 'BusinessTypeID': 1}
# {'BusinessName': 'Sea Cafe Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Buzz Bingo', 'BusinessTypeID': 1}
# {'BusinessName': 'The Duke Of Yorks Brewers Fayre', 'BusinessTypeID': 1}
# {'BusinessName': 'Walmer Baptist Church', 'BusinessTypeID': 1}
# {'BusinessName': "Jane's", 'BusinessTypeID': 1}
# {'BusinessName': 'The Haymans Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'The Beano Cafe', 'BusinessTypeID': 1}
# {'BusinessName': "Macari's", 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'The Weigh Inn', 'BusinessTypeID': 1}
# {'BusinessName': 'Brunch Cafe Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Bandstand Bakery', 'BusinessTypeID': 1}
# {'BusinessName': 'Goose on the Green', 'BusinessTypeID': 1}
# {'BusinessName': 'Dovorian', 'BusinessTypeID': 1}
# {'BusinessName': 'Bengal Spice', 'BusinessTypeID': 1}
# {'BusinessName': 'Thong Dees Thai', 'BusinessTypeID': 1}
# {'BusinessName': 'OAKLEYS', 'BusinessTypeID': 1}
# {'BusinessName': 'Doyrms Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'St.Edmonds', 'BusinessTypeID': 1}
# {'BusinessName': 'The Academy Dover', 'BusinessTypeID': 1}
# {'BusinessName': 'La Scala', 'BusinessTypeID': 1}
# {'BusinessName': 'Wellingtons', 'BusinessTypeID': 1}
# {'BusinessName': 'Fish Bar & Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Whitecliffs Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Calcutta Port', 'BusinessTypeID': 1}
# {'BusinessName': 'Momo Hub limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Pumpkin Cafe Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Zazen Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'New Moonflower', 'BusinessTypeID': 1}
# {'BusinessName': 'Dunkerleys Hotel & Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'HEY! Sushi', 'BusinessTypeID': 1}
# {'BusinessName': 'The Taphouse', 'BusinessTypeID': 1}
# {'BusinessName': 'The Courtyard Oyster Bar And Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Dylan Palace', 'BusinessTypeID': 1}
# {'BusinessName': 'Hog & Bean Deli and Eatery', 'BusinessTypeID': 1}
# {'BusinessName': "Hoody's Community Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'The Grapevine cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Hoodys Community Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Little Harriettes of Deal', 'BusinessTypeID': 1}
# {'BusinessName': 'Cin Cin', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lane', 'BusinessTypeID': 1}
# {'BusinessName': 'Wellingtons', 'BusinessTypeID': 1}
# {'BusinessName': 'Deal Beach Parlour', 'BusinessTypeID': 1}
# {'BusinessName': 'Sea View', 'BusinessTypeID': 1}
# {'BusinessName': 'Dine India, The Clarendon Hotel', 'BusinessTypeID': 1}
# {'BusinessName': 'Pop Up Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Meatball Company', 'BusinessTypeID': 1}
# {'BusinessName': 'Cabin Bar, The Clarendon Hotel', 'BusinessTypeID': 1}
# {'BusinessName': 'Salentinos', 'BusinessTypeID': 1}
# {'BusinessName': 'Aspendos', 'BusinessTypeID': 1}
# {'BusinessName': 'Starburger Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Kings Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Love Drinks', 'BusinessTypeID': 1}
# {'BusinessName': 'Strand Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Route One', 'BusinessTypeID': 1}
# {'BusinessName': 'Peckish', 'BusinessTypeID': 1}
# {'BusinessName': 'Smugglers Records', 'BusinessTypeID': 1}
# {'BusinessName': 'Royal Hotel', 'BusinessTypeID': 1}
# {'BusinessName': '81 Beach Street', 'BusinessTypeID': 1}
# {'BusinessName': 'M & Co', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks', 'BusinessTypeID': 1}
# {'BusinessName': 'McCarthy & Stone - Dover', 'BusinessTypeID': 1}
# {'BusinessName': 'Milaad Tandoori Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': "Kerry's Bakehouse & Eatery", 'BusinessTypeID': 1}
# {'BusinessName': 'Tides Leisure Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'The Dining Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Frog and Scot', 'BusinessTypeID': 1}
# {'BusinessName': 'Hope & Lane', 'BusinessTypeID': 1}
# {'BusinessName': 'Victuals & Co', 'BusinessTypeID': 1}
# {'BusinessName': 'Soul Chef Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Middle Street Fish Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'The Three Compasses', 'BusinessTypeID': 1}
# {'BusinessName': 'Spires Bistro, The Landmark Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Tea Cafe Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Miretti Pasticceria', 'BusinessTypeID': 1}
# {'BusinessName': 'Deal Town Rangers Football Club', 'BusinessTypeID': 1}
# {'BusinessName': 'The Daily Grind', 'BusinessTypeID': 1}
# {'BusinessName': "Welly's Coffeehouse and Bar", 'BusinessTypeID': 1}
# {'BusinessName': "Welly's Coffee House & Bar", 'BusinessTypeID': 1}
# {'BusinessName': "Sid's ice cream and donut parlour", 'BusinessTypeID': 1}
# {'BusinessName': 'Mileage', 'BusinessTypeID': 1}
# {'BusinessName': 'Kent Museum of the Moving Image', 'BusinessTypeID': 1}
# {'BusinessName': "Brenda's Kitchen", 'BusinessTypeID': 1}
# {'BusinessName': 'Trinity Church', 'BusinessTypeID': 1}
# {'BusinessName': 'Spindrift Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Co-op', 'BusinessTypeID': 1}
# {'BusinessName': 'White Cliffs Tandoori', 'BusinessTypeID': 1}
# {'BusinessName': 'Friendship Lunch', 'BusinessTypeID': 1}
# {'BusinessName': 'Clay Pigeon Club', 'BusinessTypeID': 1}
# {'BusinessName': "Engel's Paradise (Bistro)", 'BusinessTypeID': 1}
# {'BusinessName': 'Skylight Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'One Church Dover', 'BusinessTypeID': 1}
# {'BusinessName': 'The Smugglers Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Breakwater Tap House and Pizzeria', 'BusinessTypeID': 1}
# {'BusinessName': "Kelly's Snacks", 'BusinessTypeID': 1}
# {'BusinessName': 'Little Farthingloe Farm Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Pit Stop Snack Bar Unit 1', 'BusinessTypeID': 1}
# {'BusinessName': "Solley's Ice Cream Parlour", 'BusinessTypeID': 1}
# {'BusinessName': 'Dover District Leisure Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'St Radigunds Community Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Coombes Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Carls kitchen at caesar court', 'BusinessTypeID': 1}
# {'BusinessName': 'The Plough Inn Beefeater', 'BusinessTypeID': 1}
# {'BusinessName': 'Dover Transport Museum', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC', 'BusinessTypeID': 1}
# {'BusinessName': 'Sutton Vale Caravan Park And Country Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Tesco Family Dining Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lake House Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Crabble Corn Mill Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'The Truck Park Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Rock Rose', 'BusinessTypeID': 1}
# {'BusinessName': 'Galliford Try Building Ltd - Beeches', 'BusinessTypeID': 1}
# {'BusinessName': 'Rajmahal', 'BusinessTypeID': 1}
# {'BusinessName': 'Boost Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Mcdonalds Drive Thru', 'BusinessTypeID': 1}
# {'BusinessName': 'Bella Italia (Holiday Inn)', 'BusinessTypeID': 1}
# {'BusinessName': 'Leaf Hotel', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lamp Room', 'BusinessTypeID': 1}
# {'BusinessName': 'Kearsney Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'K J Auctions', 'BusinessTypeID': 1}
# {'BusinessName': 'Lillyroos Glamping & camping', 'BusinessTypeID': 1}
# {'BusinessName': 'Coombe Valley Raceway', 'BusinessTypeID': 1}
# {'BusinessName': 'The Pavilion', 'BusinessTypeID': 1}
# {'BusinessName': 'Dr Legumes - Harbour Arm', 'BusinessTypeID': 1}
# {'BusinessName': 'Custom Folkestone', 'BusinessTypeID': 1}
# {'BusinessName': 'Barney & The Pizza', 'BusinessTypeID': 1}
# {'BusinessName': "Dino's", 'BusinessTypeID': 1}
# {'BusinessName': 'Harbour Coffee Company', 'BusinessTypeID': 1}
# {'BusinessName': 'Putters!', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lighthouse Tasting Rooms', 'BusinessTypeID': 1}
# {'BusinessName': 'Little Switzerland Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Captains Table', 'BusinessTypeID': 1}
# {'BusinessName': 'Herberts', 'BusinessTypeID': 1}
# {'BusinessName': 'Pick Up Pintxos', 'BusinessTypeID': 1}
# {'BusinessName': 'Rocksalt', 'BusinessTypeID': 1}
# {'BusinessName': 'Folklore', 'BusinessTypeID': 1}
# {'BusinessName': 'Bella Vita', 'BusinessTypeID': 1}
# {'BusinessName': 'Diamond Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Nook', 'BusinessTypeID': 1}
# {'BusinessName': 'Touchbase Care', 'BusinessTypeID': 1}
# {'BusinessName': 'Steep Street Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'El Cortador', 'BusinessTypeID': 1}
# {'BusinessName': 'Hillside Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Lucky Chip', 'BusinessTypeID': 1}
# {'BusinessName': 'The Space Bar & Gallery', 'BusinessTypeID': 1}
# {'BusinessName': 'Misused Cocktails', 'BusinessTypeID': 1}
# {'BusinessName': 'Big Boys Fine Burger Co', 'BusinessTypeID': 1}
# {'BusinessName': 'Planet Earth Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Aspendos Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Sweet Rendezvous', 'BusinessTypeID': 1}
# {'BusinessName': 'Eleto Chocolate Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Lubens', 'BusinessTypeID': 1}
# {'BusinessName': 'Oriental Buffet', 'BusinessTypeID': 1}
# {'BusinessName': 'Wonderland Tearoom', 'BusinessTypeID': 1}
# {'BusinessName': 'Androus Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Tearooms', 'BusinessTypeID': 1}
# {'BusinessName': 'Curry Garden', 'BusinessTypeID': 1}
# {'BusinessName': 'Djangos', 'BusinessTypeID': 1}
# {'BusinessName': 'Market Square Folkestone', 'BusinessTypeID': 1}
# {'BusinessName': 'Luciano Pizzaria', 'BusinessTypeID': 1}
# {'BusinessName': 'Kathmandu House Grilled Tandoori', 'BusinessTypeID': 1}
# {'BusinessName': 'Mcdonalds Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Cube Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Sunshine Coffee and Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'RESTOCK', 'BusinessTypeID': 1}
# {'BusinessName': 'Fireaway Pizza Folkestone', 'BusinessTypeID': 1}
# {'BusinessName': "Grind n' Bake", 'BusinessTypeID': 1}
# {'BusinessName': 'La Princesse', 'BusinessTypeID': 1}
# {'BusinessName': 'Lilys American Diner', 'BusinessTypeID': 1}
# {'BusinessName': 'Abercrombies Community Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Zen Cafe Asian Diner', 'BusinessTypeID': 1}
# {'BusinessName': 'The Bao Baron', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks', 'BusinessTypeID': 1}
# {'BusinessName': 'Caffe La Delizia', 'BusinessTypeID': 1}
# {'BusinessName': 'Folkestone 51', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC', 'BusinessTypeID': 1}
# {'BusinessName': 'Bettys Pye & Mash', 'BusinessTypeID': 1}
# {'BusinessName': 'EK Baar', 'BusinessTypeID': 1}
# {'BusinessName': 'Blank Canvas Cafe Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'The Full English', 'BusinessTypeID': 1}
# {'BusinessName': 'Burger King', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Tulip', 'BusinessTypeID': 1}
# {'BusinessName': 'Asda Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Le Cafe Ganmac', 'BusinessTypeID': 1}
# {'BusinessName': 'The Little Place......Next Door', 'BusinessTypeID': 1}
# {'BusinessName': 'Laurielles Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Bella Pizza & Pasta', 'BusinessTypeID': 1}
# {'BusinessName': 'Browns Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'Gourmet Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Papas', 'BusinessTypeID': 1}
# {'BusinessName': 'Waves Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'Leas Cliff Hall', 'BusinessTypeID': 1}
# {'BusinessName': 'Roccos', 'BusinessTypeID': 1}
# {'BusinessName': 'Thong-Dees', 'BusinessTypeID': 1}
# {'BusinessName': 'Annapurna', 'BusinessTypeID': 1}
# {'BusinessName': 'Food For Thought', 'BusinessTypeID': 1}
# {'BusinessName': 'Three Hills Sports Park', 'BusinessTypeID': 1}
# {'BusinessName': "Anna's Tearoom", 'BusinessTypeID': 1}
# {'BusinessName': 'Genesis', 'BusinessTypeID': 1}
# {'BusinessName': 'Sotirios Bar & Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Rosemont Restaurant & Cocktail Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'The Waterfront Cafe Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'The Cider Works', 'BusinessTypeID': 1}
# {'BusinessName': 'Bouverie Tap', 'BusinessTypeID': 1}
# {'BusinessName': 'The Brasserie MS', 'BusinessTypeID': 1}
# {'BusinessName': 'Ali Baba Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Swiss Reassurance Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'The Brasserie MS', 'BusinessTypeID': 1}
# {'BusinessName': 'The Hideaway', 'BusinessTypeID': 1}
# {'BusinessName': 'Conchitas', 'BusinessTypeID': 1}
# {'BusinessName': 'The Radnor Arms', 'BusinessTypeID': 1}
# {'BusinessName': 'The View Hotel', 'BusinessTypeID': 1}
# {'BusinessName': 'Cocomee', 'BusinessTypeID': 1}
# {'BusinessName': 'Brew', 'BusinessTypeID': 1}
# {'BusinessName': 'Black Bull Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Sandwich Bay Bird Observatory', 'BusinessTypeID': 1}
# {'BusinessName': 'Bridge Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'Grand Hotel', 'BusinessTypeID': 1}
# {'BusinessName': 'Radnor Park Lodge', 'BusinessTypeID': 1}
# {'BusinessName': 'League of Friends Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Wards Hotel & Bistro', 'BusinessTypeID': 1}
# {'BusinessName': 'The Marquis', 'BusinessTypeID': 1}
# {'BusinessName': 'Brasserie on The Bay', 'BusinessTypeID': 1}
# {'BusinessName': 'Tunnels Tea Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'The Gardeners Kitchen Tea Rooms', 'BusinessTypeID': 1}
# {'BusinessName': 'Sorbetto', 'BusinessTypeID': 1}
# {'BusinessName': 'A La Turka', 'BusinessTypeID': 1}
# {'BusinessName': 'Alexandra Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'The Dog House & Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Alison Sea View Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Folkestone Sports Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Royal Harbour Ramsgate Brasserie', 'BusinessTypeID': 1}
# {'BusinessName': 'Updown', 'BusinessTypeID': 1}
# {'BusinessName': "Sam's Bar", 'BusinessTypeID': 1}
# {'BusinessName': 'Enoteca', 'BusinessTypeID': 1}
# {'BusinessName': 'Little Ships', 'BusinessTypeID': 1}
# {'BusinessName': 'Clique Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Thanet Bowling Club', 'BusinessTypeID': 1}
# {'BusinessName': 'The Glass House Tea Garden', 'BusinessTypeID': 1}
# {'BusinessName': 'Travellers in Italy', 'BusinessTypeID': 1}
# {'BusinessName': 'Thai Passion', 'BusinessTypeID': 1}
# {'BusinessName': 'Baker Street Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Blazing Donkey', 'BusinessTypeID': 1}
# {'BusinessName': "Gerry's Coffee & Art House", 'BusinessTypeID': 1}
# {'BusinessName': "Coco Latino & Clarey's Chocolates", 'BusinessTypeID': 1}
# {'BusinessName': 'The Arch', 'BusinessTypeID': 1}
# {'BusinessName': 'Archive Homestore', 'BusinessTypeID': 1}
# {'BusinessName': 'Ship Shape', 'BusinessTypeID': 1}
# {'BusinessName': 'Ramsgate Tandoori', 'BusinessTypeID': 1}
# {'BusinessName': 'The Greek Arch', 'BusinessTypeID': 1}
# {'BusinessName': 'Village Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'T.L.C', 'BusinessTypeID': 1}
# {'BusinessName': 'Il Tricolore', 'BusinessTypeID': 1}
# {'BusinessName': 'Sunrise Cafe Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Book Bodega', 'BusinessTypeID': 1}
# {'BusinessName': 'Corbys Tearooms', 'BusinessTypeID': 1}
# {'BusinessName': 'Jah Jah', 'BusinessTypeID': 1}
# {'BusinessName': 'The Home Front Tea Room', 'BusinessTypeID': 1}
# {'BusinessName': 'The Galley', 'BusinessTypeID': 1}
# {'BusinessName': 'Marc-Pierres Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'LA. Magnolia Ice Cream & Deli', 'BusinessTypeID': 1}
# {'BusinessName': 'Thai Orchid', 'BusinessTypeID': 1}
# {'BusinessName': 'La Magnolia', 'BusinessTypeID': 1}
# {'BusinessName': 'Curio Collectors Emporium', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lookout', 'BusinessTypeID': 1}
# {'BusinessName': 'Hearth Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC - Ramsgate', 'BusinessTypeID': 1}
# {'BusinessName': 'Zest Cafe & Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Queens Marvellous Creations & TGB', 'BusinessTypeID': 1}
# {'BusinessName': 'C and K Rileys Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Dirtee Feast', 'BusinessTypeID': 1}
# {'BusinessName': 'Souvlike - eat', 'BusinessTypeID': 1}
# {'BusinessName': 'Sage Cafe Ramsgate', 'BusinessTypeID': 1}
# {'BusinessName': 'Caffe Nero', 'BusinessTypeID': 1}
# {'BusinessName': 'Ho Wong', 'BusinessTypeID': 1}
# {'BusinessName': "Seaside's Restaurant", 'BusinessTypeID': 1}
# {'BusinessName': 'Star Nergis', 'BusinessTypeID': 1}
# {'BusinessName': 'Union Ramsgate', 'BusinessTypeID': 1}
# {'BusinessName': 'The Sun Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Louisa Bay Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Kids Brighthouse', 'BusinessTypeID': 1}
# {'BusinessName': 'Coffee Hut', 'BusinessTypeID': 1}
# {'BusinessName': "Dee's Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Tartar Frigate', 'BusinessTypeID': 1}
# {'BusinessName': 'Wyatt and Jones', 'BusinessTypeID': 1}
# {'BusinessName': 'Jetty Broadstairs', 'BusinessTypeID': 1}
# {'BusinessName': 'Panorama Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Lillyputt Mini Golf', 'BusinessTypeID': 1}
# {'BusinessName': 'The Funicular Coffeehouse', 'BusinessTypeID': 1}
# {'BusinessName': 'Flavours By Kumar', 'BusinessTypeID': 1}
# {'BusinessName': 'Saga Pavilion Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Kebbells', 'BusinessTypeID': 1}
# {'BusinessName': 'Chiappinis Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Morellis Cappuchino Bars', 'BusinessTypeID': 1}
# {'BusinessName': 'Bandstand Kiosk', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Loki', 'BusinessTypeID': 1}
# {'BusinessName': 'The Old Curiosity Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Artfuls', 'BusinessTypeID': 1}
# {'BusinessName': 'Loaf', 'BusinessTypeID': 1}
# {'BusinessName': 'Happily Ever Afters', 'BusinessTypeID': 1}
# {'BusinessName': "Eats 'n' Beats", 'BusinessTypeID': 1}
# {'BusinessName': 'The Hive Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Sandgate Vaults', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'DOS', 'BusinessTypeID': 1}
# {'BusinessName': 'La Zia Maria', 'BusinessTypeID': 1}
# {'BusinessName': 'Forts', 'BusinessTypeID': 1}
# {'BusinessName': 'Tilucks II', 'BusinessTypeID': 1}
# {'BusinessName': 'New China Inn', 'BusinessTypeID': 1}
# {'BusinessName': 'Be Me Tea Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Siam Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': "Veg'N Out", 'BusinessTypeID': 1}
# {'BusinessName': 'Aqua 43', 'BusinessTypeID': 1}
# {'BusinessName': 'Beaches Cafe Bar', 'BusinessTypeID': 1}
# {'BusinessName': "Seggari's", 'BusinessTypeID': 1}
# {'BusinessName': "Bessie's Tea Parlour", 'BusinessTypeID': 1}
# {'BusinessName': 'Seafarer Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'The Table', 'BusinessTypeID': 1}
# {'BusinessName': "St George's Community Meal", 'BusinessTypeID': 1}
# {'BusinessName': 'Osteria Posillipo', 'BusinessTypeID': 1}
# {'BusinessName': 'Sardinia', 'BusinessTypeID': 1}
# {'BusinessName': 'Samworth & Mee', 'BusinessTypeID': 1}
# {'BusinessName': "Raindell's", 'BusinessTypeID': 1}
# {'BusinessName': 'Prezzo', 'BusinessTypeID': 1}
# {'BusinessName': 'Smokehouse', 'BusinessTypeID': 1}
# {'BusinessName': 'Albarino Tapas Restaurant Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'The Pickled Herring', 'BusinessTypeID': 1}
# {'BusinessName': 'Kyoto Sushi & Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'The Dining Room', 'BusinessTypeID': 1}
# {'BusinessName': 'Smiths Coffee Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'The Little Sicilian', 'BusinessTypeID': 1}
# {'BusinessName': 'Thai Four Two', 'BusinessTypeID': 1}
# {'BusinessName': 'Helter Skelter Nursery', 'BusinessTypeID': 1}
# {'BusinessName': "Anne's Restaurant", 'BusinessTypeID': 1}
# {'BusinessName': 'Spice Cottage', 'BusinessTypeID': 1}
# {'BusinessName': 'Please Sir', 'BusinessTypeID': 1}
# {'BusinessName': 'Pork & Co Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'The Gardners Retreat Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Mr Whippets Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Crown', 'BusinessTypeID': 1}
# {'BusinessName': "Ed's Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Beano Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Orchard Lane Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'The Dog House', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Pierre', 'BusinessTypeID': 1}
# {'BusinessName': 'CCCP Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Spice Fusion', 'BusinessTypeID': 1}
# {'BusinessName': 'The Kent School of English', 'BusinessTypeID': 1}
# {'BusinessName': 'The Curry House', 'BusinessTypeID': 1}
# {'BusinessName': 'Felderland Farm Pick Your Own', 'BusinessTypeID': 1}
# {'BusinessName': "Sinatra's", 'BusinessTypeID': 1}
# {'BusinessName': 'McDonalds Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Play Wise', 'BusinessTypeID': 1}
# {'BusinessName': 'Ramsgate Sports Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC', 'BusinessTypeID': 1}
# {'BusinessName': 'The Boating Pool', 'BusinessTypeID': 1}
# {'BusinessName': 'The Boating Pool', 'BusinessTypeID': 1}
# {'BusinessName': 'Creta', 'BusinessTypeID': 1}
# {'BusinessName': 'Kope & Loko', 'BusinessTypeID': 1}
# {'BusinessName': 'The Amber Palace', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Broadstairs & St Peters Bowling Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Cardak Meze & Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Green Coffee House and Wine Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Beano Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Captain Webb Coffee Co', 'BusinessTypeID': 1}
# {'BusinessName': 'Basils', 'BusinessTypeID': 1}
# {'BusinessName': 'Gurkha Palace', 'BusinessTypeID': 1}
# {'BusinessName': "Daa's Thai Diner", 'BusinessTypeID': 1}
# {'BusinessName': 'Stonar Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Station Fish Bar & Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Eat At Toms', 'BusinessTypeID': 1}
# {'BusinessName': 'Windmill Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Eythorne Station Tea Room', 'BusinessTypeID': 1}
# {'BusinessName': 'The Old Pharmacy', 'BusinessTypeID': 1}
# {'BusinessName': 'The Beano Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Namaste Sandwich', 'BusinessTypeID': 1}
# {'BusinessName': 'Luigis', 'BusinessTypeID': 1}
# {'BusinessName': 'The Deep Blue', 'BusinessTypeID': 1}
# {'BusinessName': 'St Lawrence Bowls Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Thanet Winter Shelter', 'BusinessTypeID': 1}
# {'BusinessName': 'Broadstairs English Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Bell Hotel', 'BusinessTypeID': 1}
# {'BusinessName': 'Beanos Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Sandwich Wildlife Park', 'BusinessTypeID': 1}
# {'BusinessName': 'Sandwich Wildlife Park Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'My Happy Place Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Haven', 'BusinessTypeID': 1}
# {'BusinessName': 'The Toll Bridge', 'BusinessTypeID': 1}
# {'BusinessName': 'Tan-Bueno', 'BusinessTypeID': 1}
# {'BusinessName': 'Di Vino', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Goats That Dance', 'BusinessTypeID': 1}
# {'BusinessName': 'Everest Spice Fusion', 'BusinessTypeID': 1}
# {'BusinessName': 'Army - Premier Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Army - Junior Ranks Mess', 'BusinessTypeID': 1}
# {'BusinessName': 'No Name Shop and Bistro', 'BusinessTypeID': 1}
# {'BusinessName': 'Army - Officers Mess', 'BusinessTypeID': 1}
# {'BusinessName': 'The Sandwich Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'The Waiting Room', 'BusinessTypeID': 1}
# {'BusinessName': 'My Thai Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Bella Amalfi', 'BusinessTypeID': 1}
# {'BusinessName': 'Bannatynes Health Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Finns', 'BusinessTypeID': 1}
# {'BusinessName': 'Dawns Delight', 'BusinessTypeID': 1}
# {'BusinessName': 'Army - Sergeants Mess', 'BusinessTypeID': 1}
# {'BusinessName': 'Smugglers Beer and Music Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Woodpecker Court Youth Activities', 'BusinessTypeID': 1}
# {'BusinessName': 'The Strand Street Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Chai Coffee Nashta', 'BusinessTypeID': 1}
# {'BusinessName': 'New Himalayan Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'India Village Tandoori', 'BusinessTypeID': 1}
# {'BusinessName': 'The Smokehouse', 'BusinessTypeID': 1}
# {'BusinessName': 'Mermaids Locker', 'BusinessTypeID': 1}
# {'BusinessName': 'Hays Shack', 'BusinessTypeID': 1}
# {'BusinessName': 'Bakers Dozen', 'BusinessTypeID': 1}
# {'BusinessName': 'Refresh Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Pumpkin', 'BusinessTypeID': 1}
# {'BusinessName': 'Light Railway Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'St Lawrence Tandoori', 'BusinessTypeID': 1}
# {'BusinessName': 'Sexy Burger', 'BusinessTypeID': 1}
# {'BusinessName': 'Dungeness A Power Station', 'BusinessTypeID': 1}
# {'BusinessName': 'Java Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Wings n Dat', 'BusinessTypeID': 1}
# {'BusinessName': 'Java 2 Go', 'BusinessTypeID': 1}
# {'BusinessName': 'Lemon Leaf Restaurant & Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Curious Crafts of Cheriton & Tearoom', 'BusinessTypeID': 1}
# {'BusinessName': 'Prince of India', 'BusinessTypeID': 1}
# {'BusinessName': 'Daows Thai Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': '3 in 1 Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Kidz Planet', 'BusinessTypeID': 1}
# {'BusinessName': 'The Pavilion Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Joss Bay Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'EDF  Dungeness B Power Station', 'BusinessTypeID': 1}
# {'BusinessName': 'Laurel Court Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'The Creative Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Lilys', 'BusinessTypeID': 1}
# {'BusinessName': 'Aspendos Hawkinge', 'BusinessTypeID': 1}
# {'BusinessName': 'The Cooks Table', 'BusinessTypeID': 1}
# {'BusinessName': 'The Corner Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'Buttons Pre-School (Fegans)', 'BusinessTypeID': 1}
# {'BusinessName': 'Hawkinge House', 'BusinessTypeID': 1}
# {'BusinessName': 'Under 1 Roof Kids Thanet', 'BusinessTypeID': 1}
# {'BusinessName': 'Stewarts Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Elvington & Eythorne Heritage Group', 'BusinessTypeID': 1}
# {'BusinessName': 'Blue Apple Contract Catering', 'BusinessTypeID': 1}
# {'BusinessName': 'Rosie Lea Tea', 'BusinessTypeID': 1}
# {'BusinessName': 'Staple', 'BusinessTypeID': 1}
# {'BusinessName': 'Golf Club Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Halfway House Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Naafi Gb Cinque Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Hawkinge Community Football & Sports', 'BusinessTypeID': 1}
# {'BusinessName': 'Army - Comanding Officers Mess', 'BusinessTypeID': 1}
# {'BusinessName': 'Army - Risborough - Napier 33 (Other', 'BusinessTypeID': 1}
# {'BusinessName': 'Beano Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Peninsula', 'BusinessTypeID': 1}
# {'BusinessName': 'LEON', 'BusinessTypeID': 1}
# {'BusinessName': 'Dee Dees cafe @ The Range', 'BusinessTypeID': 1}
# {'BusinessName': 'Customer Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC - Westwood', 'BusinessTypeID': 1}
# {'BusinessName': 'T42 Community Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Sexy Burger', 'BusinessTypeID': 1}
# {'BusinessName': 'Lunch Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Tesco Customer Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Botany Bay Beach Kiosk', 'BusinessTypeID': 1}
# {'BusinessName': 'Colonels Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Battle of Britain Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Ramsgate Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Cabin Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lighthouse Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Ess', 'BusinessTypeID': 1}
# {'BusinessName': 'Kent Army Cadet Force - Block B, Dibgate Camp', 'BusinessTypeID': 1}
# {'BusinessName': 'Baypoint Sandwich', 'BusinessTypeID': 1}
# {'BusinessName': 'Able Catering', 'BusinessTypeID': 1}
# {'BusinessName': 'Revolution Skate Park', 'BusinessTypeID': 1}
# {'BusinessName': 'The Sticky Wickett Sports Bar', 'BusinessTypeID': 1}
# {'BusinessName': "Dee Dee's Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Bannatynes Health Club', 'BusinessTypeID': 1}
# {'BusinessName': 'SS Machinery UK', 'BusinessTypeID': 1}
# {'BusinessName': 'Harris & Hoole Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Staff Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'The Gents Lodge', 'BusinessTypeID': 1}
# {'BusinessName': "Taddy's Barn Tea Room", 'BusinessTypeID': 1}
# {'BusinessName': 'St Phillips Church', 'BusinessTypeID': 1}
# {'BusinessName': 'McDonalds', 'BusinessTypeID': 1}
# {'BusinessName': 'Fairways Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Holy Pundit', 'BusinessTypeID': 1}
# {'BusinessName': 'The Canterbury Bell', 'BusinessTypeID': 1}
# {'BusinessName': "SAM's", 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe on the Beach', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee Drive Thru', 'BusinessTypeID': 1}
# {'BusinessName': 'La Gare', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks', 'BusinessTypeID': 1}
# {'BusinessName': 'Train Crew Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Burger King', 'BusinessTypeID': 1}
# {'BusinessName': 'PTB Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'The Tenth', 'BusinessTypeID': 1}
# {'BusinessName': 'Leon', 'BusinessTypeID': 1}
# {'BusinessName': 'Pizza Hut Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Dunelm Mill', 'BusinessTypeID': 1}
# {'BusinessName': 'Sene Valley Golf Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Ask', 'BusinessTypeID': 1}
# {'BusinessName': 'Thai Village Restaurant & Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Grosvenor Casino', 'BusinessTypeID': 1}
# {'BusinessName': 'Coffee Corner', 'BusinessTypeID': 1}
# {'BusinessName': 'Vue Cinema', 'BusinessTypeID': 1}
# {'BusinessName': 'Mecca Bingo', 'BusinessTypeID': 1}
# {'BusinessName': "Nando's", 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Nero', 'BusinessTypeID': 1}
# {'BusinessName': 'Bella Italia', 'BusinessTypeID': 1}
# {'BusinessName': 'The Garden Gate Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': "Frankie & Benny's", 'BusinessTypeID': 1}
# {'BusinessName': 'Kaspars', 'BusinessTypeID': 1}
# {'BusinessName': 'The Waterfront', 'BusinessTypeID': 1}
# {'BusinessName': 'Toby Carvery Thanet', 'BusinessTypeID': 1}
# {'BusinessName': 'Elham Valley Line Trust', 'BusinessTypeID': 1}
# {'BusinessName': 'Hooden Horse', 'BusinessTypeID': 1}
# {'BusinessName': 'Greggs', 'BusinessTypeID': 1}
# {'BusinessName': 'Burger King Uk Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Grove Cafe @ Folkestone Garden Centr', 'BusinessTypeID': 1}
# {'BusinessName': 'Coppers', 'BusinessTypeID': 1}
# {'BusinessName': 'Millmead Early Years Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Twenty Four', 'BusinessTypeID': 1}
# {'BusinessName': 'The Conservatory', 'BusinessTypeID': 1}
# {'BusinessName': 'Torbay Of Hythe Fish & Chips', 'BusinessTypeID': 1}
# {'BusinessName': 'The Nutmeg Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Bellagio', 'BusinessTypeID': 1}
# {'BusinessName': 'The Tea Garden Hythe', 'BusinessTypeID': 1}
# {'BusinessName': 'Brooks Tearoom', 'BusinessTypeID': 1}
# {'BusinessName': 'The Cooks Table', 'BusinessTypeID': 1}
# {'BusinessName': 'Just The Ticket Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Taste of Kathmandu', 'BusinessTypeID': 1}
# {'BusinessName': 'Truly Scrumptious', 'BusinessTypeID': 1}
# {'BusinessName': 'Vinodhon', 'BusinessTypeID': 1}
# {'BusinessName': 'Gingers Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Root Hythe', 'BusinessTypeID': 1}
# {'BusinessName': 'Sunshine Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Simla Brasserie', 'BusinessTypeID': 1}
# {'BusinessName': 'Doveys & Moore', 'BusinessTypeID': 1}
# {'BusinessName': "Ivy's of Hythe", 'BusinessTypeID': 1}
# {'BusinessName': 'Veganly Convenient', 'BusinessTypeID': 1}
# {'BusinessName': 'Everest Inn', 'BusinessTypeID': 1}
# {'BusinessName': 'Thailand Tom', 'BusinessTypeID': 1}
# {'BusinessName': 'Lashings Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Mit Milch', 'BusinessTypeID': 1}
# {'BusinessName': 'Global Generation Church', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lounge', 'BusinessTypeID': 1}
# {'BusinessName': 'Nincomsoup', 'BusinessTypeID': 1}
# {'BusinessName': "Aunty T's Kitchen", 'BusinessTypeID': 1}
# {'BusinessName': 'Palm Bay Cafe', 'BusinessTypeID': 1}
# {'BusinessName': "Gloria's Lounge & Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Jet Ski World Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Vinnys Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Skinny Dip Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'The Oval Bandstand And Lawns', 'BusinessTypeID': 1}
# {'BusinessName': 'R & Z Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Aroma Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'R & Z Ltd Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'The Bangkok Thai', 'BusinessTypeID': 1}
# {'BusinessName': 'Greenly Coffee Bar', 'BusinessTypeID': 1}
# {'BusinessName': "Ouma's Kitchen", 'BusinessTypeID': 1}
# {'BusinessName': 'RH&DR Hythe Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Kussan', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Continental', 'BusinessTypeID': 1}
# {'BusinessName': 'Cliftonville Outdoor Bowls Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Tom Thumb Theatre', 'BusinessTypeID': 1}
# {'BusinessName': 'Hide And Fox', 'BusinessTypeID': 1}
# {'BusinessName': 'Pasha', 'BusinessTypeID': 1}
# {'BusinessName': 'TBS Pop UP', 'BusinessTypeID': 1}
# {'BusinessName': 'Cliffs', 'BusinessTypeID': 1}
# {'BusinessName': 'Secret Spices', 'BusinessTypeID': 1}
# {'BusinessName': 'Demetrios / Fishos Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Happy Cafe & Family Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'New Life Family Church', 'BusinessTypeID': 1}
# {'BusinessName': 'Dalby Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Number 37', 'BusinessTypeID': 1}
# {'BusinessName': 'Olympia Cafe', 'BusinessTypeID': 1}
# {'BusinessName': "Bugsy's Bowling Centre", 'BusinessTypeID': 1}
# {'BusinessName': 'Mar Mar', 'BusinessTypeID': 1}
# {'BusinessName': 'St Johns Community Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'The Boat Shed Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Golden Curry', 'BusinessTypeID': 1}
# {'BusinessName': 'Kitchen Social & Cookery Club cic', 'BusinessTypeID': 1}
# {'BusinessName': 'Rendezvous Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'HS Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'K G Winters', 'BusinessTypeID': 1}
# {'BusinessName': 'We Are Here', 'BusinessTypeID': 1}
# {'BusinessName': 'Riz Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Tivoli Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Martello Pub', 'BusinessTypeID': 1}
# {'BusinessName': 'The Best Beano Cafe & Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Haeckels', 'BusinessTypeID': 1}
# {'BusinessName': 'Forts Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Daisy', 'BusinessTypeID': 1}
# {'BusinessName': 'Ty - 8', 'BusinessTypeID': 1}
# {'BusinessName': 'Bar Nothing', 'BusinessTypeID': 1}
# {'BusinessName': 'The Salvation Army', 'BusinessTypeID': 1}
# {'BusinessName': 'Mia Papas Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'The Margate Caves Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Storeroom', 'BusinessTypeID': 1}
# {'BusinessName': 'McDonalds', 'BusinessTypeID': 1}
# {'BusinessName': 'George Burgers', 'BusinessTypeID': 1}
# {'BusinessName': 'Brockhill Country Park', 'BusinessTypeID': 1}
# {'BusinessName': 'New Beach Holiday Village', 'BusinessTypeID': 1}
# {'BusinessName': 'Milk and Cookie', 'BusinessTypeID': 1}
# {'BusinessName': 'Curve Coffee Store', 'BusinessTypeID': 1}
# {'BusinessName': 'Infinity Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'The George & Heart', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Modern Provider', 'BusinessTypeID': 1}
# {'BusinessName': 'Elsewhere', 'BusinessTypeID': 1}
# {'BusinessName': 'Subway', 'BusinessTypeID': 1}
# {'BusinessName': 'Burger Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Palms Pizza', 'BusinessTypeID': 1}
# {'BusinessName': 'Biggles Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Ministry of Pies', 'BusinessTypeID': 1}
# {'BusinessName': 'Scissortail Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Edessa', 'BusinessTypeID': 1}
# {'BusinessName': 'The Little Fish Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Seaside Cake Parlour', 'BusinessTypeID': 1}
# {'BusinessName': 'Kawa', 'BusinessTypeID': 1}
# {'BusinessName': 'Giorgios', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Darcy', 'BusinessTypeID': 1}
# {'BusinessName': 'Margate Masonic Lodge', 'BusinessTypeID': 1}
# {'BusinessName': 'Silver Slipper Performing Arts Schoo', 'BusinessTypeID': 1}
# {'BusinessName': 'Mullins Brasserie', 'BusinessTypeID': 1}
# {'BusinessName': "Bow's Kitchen", 'BusinessTypeID': 1}
# {'BusinessName': "Ralph's", 'BusinessTypeID': 1}
# {'BusinessName': 'New Street Bistro', 'BusinessTypeID': 1}
# {'BusinessName': 'Mama Jinny Thai Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Beano Cafe & Family Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe de China', 'BusinessTypeID': 1}
# {'BusinessName': "L'Olivo", 'BusinessTypeID': 1}
# {'BusinessName': 'Kookidoe', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC - Margate', 'BusinessTypeID': 1}
# {'BusinessName': 'Zen by the Sea', 'BusinessTypeID': 1}
# {'BusinessName': 'The Margate Bookshop', 'BusinessTypeID': 1}
# {'BusinessName': 'The Greedy Cow', 'BusinessTypeID': 1}
# {'BusinessName': 'Hantverk & Found', 'BusinessTypeID': 1}
# {'BusinessName': 'Wildes', 'BusinessTypeID': 1}
# {'BusinessName': "Olby's Soul Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Bottega Caruso, The Crown Gallery', 'BusinessTypeID': 1}
# {'BusinessName': 'Masala Gate', 'BusinessTypeID': 1}
# {'BusinessName': 'Life is a Beach', 'BusinessTypeID': 1}
# {'BusinessName': 'Alexandria Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Waverley House', 'BusinessTypeID': 1}
# {'BusinessName': 'The Greek Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'The Ambrette', 'BusinessTypeID': 1}
# {'BusinessName': 'Pan Asian Cuisine', 'BusinessTypeID': 1}
# {'BusinessName': 'Harbour Cafe Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'The Med', 'BusinessTypeID': 1}
# {'BusinessName': 'The Margate Coffee Shed', 'BusinessTypeID': 1}
# {'BusinessName': 'SLAB', 'BusinessTypeID': 1}
# {'BusinessName': "Charlie's", 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe G', 'BusinessTypeID': 1}
# {'BusinessName': 'Beet Bar', 'BusinessTypeID': 1}
# {'BusinessName': "Angela's of Margate", 'BusinessTypeID': 1}
# {'BusinessName': 'Sands Hotel Margate Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Big Shot', 'BusinessTypeID': 1}
# {'BusinessName': 'The Glass Jar', 'BusinessTypeID': 1}
# {'BusinessName': 'Buoy and Oyster', 'BusinessTypeID': 1}
# {'BusinessName': 'The Candy Stop', 'BusinessTypeID': 1}
# {'BusinessName': 'Sands Restaurant & Cafe Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Sea Shed', 'BusinessTypeID': 1}
# {'BusinessName': 'Kids Mayhem Clubworld', 'BusinessTypeID': 1}
# {'BusinessName': "Dory's", 'BusinessTypeID': 1}
# {'BusinessName': 'Looking Ahead - Tea Rooms', 'BusinessTypeID': 1}
# {'BusinessName': 'Pamela at The Turner Contemporary', 'BusinessTypeID': 1}
# {'BusinessName': 'The Old Dairy', 'BusinessTypeID': 1}
# {'BusinessName': 'Great British Pizza Company Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Goodnestone Park', 'BusinessTypeID': 1}
# {'BusinessName': '13 Fitness', 'BusinessTypeID': 1}
# {'BusinessName': 'Manor House Nursery School', 'BusinessTypeID': 1}
# {'BusinessName': 'Lydd Kart Circuit', 'BusinessTypeID': 1}
# {'BusinessName': 'Hartsdown Leisure Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Cooked with Love', 'BusinessTypeID': 1}
# {'BusinessName': 'Aylesham And Snowdowns Bowls Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Nelson Park Riding Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Dive', 'BusinessTypeID': 1}
# {'BusinessName': 'Staple', 'BusinessTypeID': 1}
# {'BusinessName': 'The Sargasso', 'BusinessTypeID': 1}
# {'BusinessName': 'Coffee Station', 'BusinessTypeID': 1}
# {'BusinessName': 'McDonalds Restaurant And Drive Through', 'BusinessTypeID': 1}
# {'BusinessName': 'Minster Tandoori', 'BusinessTypeID': 1}
# {'BusinessName': 'Pan Asian Cuisine', 'BusinessTypeID': 1}
# {'BusinessName': 'Aylesham Welfare Leisure Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'The Bus Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Pork And Company Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Garage Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Aylesham Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Littlestone Meeting Hub', 'BusinessTypeID': 1}
# {'BusinessName': 'Bucket & Spade Coffee Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Beach 48', 'BusinessTypeID': 1}
# {'BusinessName': 'The Galley', 'BusinessTypeID': 1}
# {'BusinessName': 'Roses Tearoom', 'BusinessTypeID': 1}
# {'BusinessName': 'Cardamom', 'BusinessTypeID': 1}
# {'BusinessName': 'The Hot Potato Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Treasure Chest', 'BusinessTypeID': 1}
# {'BusinessName': 'Ali Raj', 'BusinessTypeID': 1}
# {'BusinessName': 'Ultimate Eats & Treats', 'BusinessTypeID': 1}
# {'BusinessName': 'Pens Kafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Snack Bar MW Amusements', 'BusinessTypeID': 1}
# {'BusinessName': 'The Mortar and Pestle', 'BusinessTypeID': 1}
# {'BusinessName': 'Village Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Tandoori Hut', 'BusinessTypeID': 1}
# {'BusinessName': 'Casa Pizzeria & Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Westbrook Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Drink Margate', 'BusinessTypeID': 1}
# {'BusinessName': 'Ship Inn', 'BusinessTypeID': 1}
# {'BusinessName': "Jemima's Tea Room", 'BusinessTypeID': 1}
# {'BusinessName': 'Coffee Lounge', 'BusinessTypeID': 1}
# {'BusinessName': 'Fifty 2', 'BusinessTypeID': 1}
# {'BusinessName': 'Romney, Hythe & Dymchurch Railway', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee Drive Thru', 'BusinessTypeID': 1}
# {'BusinessName': 'The Bay Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Elevenses', 'BusinessTypeID': 1}
# {'BusinessName': 'Orlandos Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Amadeus Trattoria', 'BusinessTypeID': 1}
# {'BusinessName': 'Strokes Adventure Golf', 'BusinessTypeID': 1}
# {'BusinessName': 'Merlin Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Zimbos', 'BusinessTypeID': 1}
# {'BusinessName': 'Smugglers Retreat Table Table', 'BusinessTypeID': 1}
# {'BusinessName': 'The Marsh Maze', 'BusinessTypeID': 1}
# {'BusinessName': 'Fennel', 'BusinessTypeID': 1}
# {'BusinessName': 'Marlie Farm Holiday Village', 'BusinessTypeID': 1}
# {'BusinessName': 'Flavours by Kumar', 'BusinessTypeID': 1}
# {'BusinessName': 'BMS Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'China China', 'BusinessTypeID': 1}
# {'BusinessName': 'Brew 32', 'BusinessTypeID': 1}
# {'BusinessName': 'The Coffee Cabin', 'BusinessTypeID': 1}
# {'BusinessName': 'The Coach House', 'BusinessTypeID': 1}
# {'BusinessName': 'Diamond BBQ Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': "Nikki D's Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Romney Spice', 'BusinessTypeID': 1}
# {'BusinessName': 'Balance Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Fish & Peri', 'BusinessTypeID': 1}
# {'BusinessName': 'Bakery 64', 'BusinessTypeID': 1}
# {'BusinessName': 'Ruzzo', 'BusinessTypeID': 1}
# {'BusinessName': 'Kerrys Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Ess', 'BusinessTypeID': 1}
# {'BusinessName': 'Army - Lydd 20 (Other Ranks Mess)', 'BusinessTypeID': 1}
# {'BusinessName': 'Deblyns', 'BusinessTypeID': 1}
# {'BusinessName': 'Santa Fe', 'BusinessTypeID': 1}
# {'BusinessName': 'Cosy Tea Room', 'BusinessTypeID': 1}
# {'BusinessName': 'H Fish and Chips', 'BusinessTypeID': 1}
# {'BusinessName': 'The Curry Lounge', 'BusinessTypeID': 1}
# {'BusinessName': 'Cooks Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Mermikides Community Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'The Picnic Hut', 'BusinessTypeID': 1}
# {'BusinessName': 'Pit Stop / The Reel Fish & Chip Co', 'BusinessTypeID': 1}
# {'BusinessName': 'Chopstix Noodle Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe 24', 'BusinessTypeID': 1}
# {'BusinessName': "Millie's Beach Bar", 'BusinessTypeID': 1}
# {'BusinessName': 'Wingham Wildlife Park', 'BusinessTypeID': 1}
# {'BusinessName': "The St Mildred's Bay", 'BusinessTypeID': 1}
# {'BusinessName': 'The Best Beano Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Hot Wood Pizza', 'BusinessTypeID': 1}
# {'BusinessName': 'Beano Cafe', 'BusinessTypeID': 1}
# ...
# {'BusinessName': 'Phoenix Community Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': "BB's Coffee & Muffins", 'BusinessTypeID': 1}
# {'BusinessName': 'Burger King', 'BusinessTypeID': 1}
# {'BusinessName': 'Food Hall', 'BusinessTypeID': 1}
# {'BusinessName': 'Waffle & More', 'BusinessTypeID': 1}
# {'BusinessName': 'Redricks Lake Cafe Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks', 'BusinessTypeID': 1}
# {'BusinessName': "McDonald's", 'BusinessTypeID': 1}
# {'BusinessName': 'SpiceBoys', 'BusinessTypeID': 1}
# {'BusinessName': 'Tim Hortons Cafe & Bake Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa', 'BusinessTypeID': 1}
# {'BusinessName': 'Brick Lane Bagel Co.', 'BusinessTypeID': 1}
# {'BusinessName': 'Pizza Hut Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Cineworld Cinemas', 'BusinessTypeID': 1}
# {'BusinessName': 'Tasty Grill Express / Bonito Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Pizza Hut', 'BusinessTypeID': 1}
# {'BusinessName': 'The Sandwich Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Harolds Park Riding Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'Creams Harlow / Cafe Harlow Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Sticky Sisters', 'BusinessTypeID': 1}
# {'BusinessName': 'Couzens Bakery And Coffee Lounge', 'BusinessTypeID': 1}
# {'BusinessName': 'Greek Flavours', 'BusinessTypeID': 1}
# {'BusinessName': 'P5 Lounge', 'BusinessTypeID': 1}
# {'BusinessName': 'The  Playbarn', 'BusinessTypeID': 1}
# {'BusinessName': 'New Market Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'King Du Noodle Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Elite', 'BusinessTypeID': 1}
# {'BusinessName': 'Dixy Chicken', 'BusinessTypeID': 1}
# {'BusinessName': 'Spurriers House Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Soul2Spice', 'BusinessTypeID': 1}
# {'BusinessName': 'Ripped Gym Ltd', 'BusinessTypeID': 1}
# {'BusinessName': "Hazel's Kitchen", 'BusinessTypeID': 1}
# {'BusinessName': 'Challenge Active', 'BusinessTypeID': 1}
# {'BusinessName': 'Talkington Bates Ltd, Canteen', 'BusinessTypeID': 1}
# {'BusinessName': 'Redwings  Ada Cole', 'BusinessTypeID': 1}
# {'BusinessName': 'Arthur Findlay College', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa', 'BusinessTypeID': 1}
# {'BusinessName': "Wild 'N' Wacky Ltd.", 'BusinessTypeID': 1}
# {'BusinessName': 'Chandini Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': "Vince's Restaurant and Bar", 'BusinessTypeID': 1}
# {'BusinessName': 'Apollo Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Le Spice', 'BusinessTypeID': 1}
# {'BusinessName': 'Kalik Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Caffe La Vita', 'BusinessTypeID': 1}
# {'BusinessName': 'Compass Group PLC', 'BusinessTypeID': 1}
# {'BusinessName': 'Harlow Centre For Outdoor Learning', 'BusinessTypeID': 1}
# {'BusinessName': 'The Moorhen', 'BusinessTypeID': 1}
# {'BusinessName': 'The Phoenix Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Diageo (Restaurant) - Sodexo', 'BusinessTypeID': 1}
# {'BusinessName': "Willett's Cafe Diner", 'BusinessTypeID': 1}
# {'BusinessName': 'Benhams Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Elsenham Memorial Hall', 'BusinessTypeID': 1}
# {'BusinessName': 'Herts And Essex Community Hospital', 'BusinessTypeID': 1}
# {'BusinessName': 'Chopstix Brand Europe Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Burger King', 'BusinessTypeID': 1}
# {'BusinessName': 'KFC', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks Kiosk', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks Drive Thru', 'BusinessTypeID': 1}
# {'BusinessName': 'Good Breakfast', 'BusinessTypeID': 1}
# {'BusinessName': 'Subway', 'BusinessTypeID': 1}
# {'BusinessName': 'Stumps Heccsport', 'BusinessTypeID': 1}
# {'BusinessName': 'Jaal Bar & Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Napier Catering Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Baan Thitiya Thai Cuisine', 'BusinessTypeID': 1}
# {'BusinessName': 'Stortford Gymnastics Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Britannia', 'BusinessTypeID': 1}
# {'BusinessName': 'Canteen Caffe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Baking Room', 'BusinessTypeID': 1}
# {'BusinessName': 'Harlow Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Rhodes Art Complex', 'BusinessTypeID': 1}
# {'BusinessName': 'The Pizza Guys', 'BusinessTypeID': 1}
# {'BusinessName': 'Bridge The Gap', 'BusinessTypeID': 1}
# {'BusinessName': 'The Rivermill Chinese Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Kings Café', 'BusinessTypeID': 1}
# {'BusinessName': 'HQ Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Mint Leaf', 'BusinessTypeID': 1}
# {'BusinessName': 'Bonnefirebox Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Bishops Stortford Escape Rooms', 'BusinessTypeID': 1}
# {'BusinessName': 'Leape Pop-up Catering', 'BusinessTypeID': 1}
# {'BusinessName': 'The Bombay Butler', 'BusinessTypeID': 1}
# {'BusinessName': 'Pino Pizza & Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'The Station Pizza', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Masala', 'BusinessTypeID': 1}
# {'BusinessName': 'Burgers Lab', 'BusinessTypeID': 1}
# {'BusinessName': 'Mountfitchet Castle', 'BusinessTypeID': 1}
# {'BusinessName': 'Crimson 8', 'BusinessTypeID': 1}
# {'BusinessName': 'Atrium Caterers', 'BusinessTypeID': 1}
# {'BusinessName': 'Uppers', 'BusinessTypeID': 1}
# {'BusinessName': 'The Lower Street Brasserie', 'BusinessTypeID': 1}
# {'BusinessName': 'Stansted Mountfichet Social Club', 'BusinessTypeID': 1}
# {'BusinessName': 'The Cork House', 'BusinessTypeID': 1}
# {'BusinessName': 'Stansted Youth Centre', 'BusinessTypeID': 1}
# {'BusinessName': "Cafe Yeoman's", 'BusinessTypeID': 1}
# {'BusinessName': 'Bear And Eden', 'BusinessTypeID': 1}
# {'BusinessName': 'Flames', 'BusinessTypeID': 1}
# {'BusinessName': 'Rubys', 'BusinessTypeID': 1}
# {'BusinessName': "Afonso's Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Tradizioni Italiane', 'BusinessTypeID': 1}
# {'BusinessName': 'Luso Flavours', 'BusinessTypeID': 1}
# {'BusinessName': 'Ace Of Lanes', 'BusinessTypeID': 1}
# {'BusinessName': 'Brohmon', 'BusinessTypeID': 1}
# {'BusinessName': 'The Villa Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Origin Tea & Coffee Company LTD', 'BusinessTypeID': 1}
# {'BusinessName': 'Shadhona', 'BusinessTypeID': 1}
# {'BusinessName': 'Ora Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Russell Up Events Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Nuffield Health', 'BusinessTypeID': 1}
# {'BusinessName': 'Gourmet Oriental', 'BusinessTypeID': 1}
# {'BusinessName': 'Pop In Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Pizza Hut', 'BusinessTypeID': 1}
# {'BusinessName': 'Coffee House', 'BusinessTypeID': 1}
# {'BusinessName': 'Cibo', 'BusinessTypeID': 1}
# {'BusinessName': 'The Toaster', 'BusinessTypeID': 1}
# {'BusinessName': 'South Street Pantry', 'BusinessTypeID': 1}
# {'BusinessName': 'Skew Restaurant & Oyster Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Thyme', 'BusinessTypeID': 1}
# {'BusinessName': 'CHESHUNT CHATEAU CAFÉ LTD', 'BusinessTypeID': 1}
# {'BusinessName': 'Wattle & Co.', 'BusinessTypeID': 1}
# {'BusinessName': 'Rindio Cafe Deli', 'BusinessTypeID': 1}
# {'BusinessName': 'Epiphany Clothing', 'BusinessTypeID': 1}
# {'BusinessName': 'Debden Pentecostal Church', 'BusinessTypeID': 1}
# {'BusinessName': 'Chateau Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'F.Cooke Pie And Mash', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'The Yeerologist At Eat17', 'BusinessTypeID': 1}
# {'BusinessName': 'Sukira Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Carne Street Food', 'BusinessTypeID': 1}
# {'BusinessName': 'Eat17 Kitchen', 'BusinessTypeID': 1}
# {'BusinessName': 'Waffle On', 'BusinessTypeID': 1}
# {'BusinessName': 'The Chicken Hatch', 'BusinessTypeID': 1}
# {'BusinessName': 'Dine Contract Catering Ltd At Bidfood Staff Canteen', 'BusinessTypeID': 1}
# {'BusinessName': 'H@me And Eat', 'BusinessTypeID': 1}
# {'BusinessName': "Nando's", 'BusinessTypeID': 1}
# {'BusinessName': 'Phillers', 'BusinessTypeID': 1}
# {'BusinessName': 'Touchpoint', 'BusinessTypeID': 1}
# {'BusinessName': 'Hotel Chocolat Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Vire', 'BusinessTypeID': 1}
# {'BusinessName': 'Caffe Nero', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Mocha', 'BusinessTypeID': 1}
# {'BusinessName': 'Peach', 'BusinessTypeID': 1}
# {'BusinessName': 'Bridge Cafe', 'BusinessTypeID': 1}
# {'BusinessName': "Buffalo Joe's", 'BusinessTypeID': 1}
# {'BusinessName': 'No 7 Palmers', 'BusinessTypeID': 1}
# {'BusinessName': "One Thai Bishop's Stortford", 'BusinessTypeID': 1}
# {'BusinessName': 'Greedy Greek', 'BusinessTypeID': 1}
# {'BusinessName': 'Wood Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Pircio Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Yummys', 'BusinessTypeID': 1}
# {'BusinessName': 'Host', 'BusinessTypeID': 1}
# {'BusinessName': 'Dough And Co Burger Amour Stortford Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Greens Organics Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Giggling Squid', 'BusinessTypeID': 1}
# {'BusinessName': "Roni's Restaurant", 'BusinessTypeID': 1}
# {'BusinessName': 'The Lemon Tree', 'BusinessTypeID': 1}
# {'BusinessName': 'Salute E Baci Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Rosey Lea', 'BusinessTypeID': 1}
# {'BusinessName': 'Caffe Inn', 'BusinessTypeID': 1}
# {'BusinessName': 'Alessandro Di Leo Pasticceria Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Flames Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Jades', 'BusinessTypeID': 1}
# {'BusinessName': "Albert's", 'BusinessTypeID': 1}
# {'BusinessName': 'Prezzo', 'BusinessTypeID': 1}
# {'BusinessName': 'Cote Brasserie', 'BusinessTypeID': 1}
# {'BusinessName': 'FRANCO MANCA', 'BusinessTypeID': 1}
# {'BusinessName': 'Cote Brasserie', 'BusinessTypeID': 1}
# {'BusinessName': 'Pizza Express/Mac & Wings', 'BusinessTypeID': 1}
# {'BusinessName': "Boar's Head Steak House And Grill", 'BusinessTypeID': 1}
# {'BusinessName': 'Tandoori Cottage Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Huckleberry Chicken', 'BusinessTypeID': 1}
# {'BusinessName': 'Folies', 'BusinessTypeID': 1}
# {'BusinessName': 'Zara Indian Dining', 'BusinessTypeID': 1}
# {'BusinessName': 'Mountbatten', 'BusinessTypeID': 1}
# {'BusinessName': 'Eat Sheaf', 'BusinessTypeID': 1}
# {'BusinessName': 'Elder Street Cafe & Deli', 'BusinessTypeID': 1}
# {'BusinessName': 'Debden Lunch Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Yuva', 'BusinessTypeID': 1}
# {'BusinessName': 'Blues Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'The Doorstep Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Tyndalls', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Chives Catering', 'BusinessTypeID': 1}
# {'BusinessName': 'Just at the Station', 'BusinessTypeID': 1}
# {'BusinessName': 'Sewards End Village Hall', 'BusinessTypeID': 1}
# {'BusinessName': 'Servest Food Company', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'The Boathouse Cafe Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'River Palace Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Rosey Lea', 'BusinessTypeID': 1}
# {'BusinessName': 'Cortland Fibron BX', 'BusinessTypeID': 1}
# {'BusinessName': 'Henry Moore Foundation Visitor Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Copleys', 'BusinessTypeID': 1}
# {'BusinessName': 'Beefeater', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa Coffee', 'BusinessTypeID': 1}
# {'BusinessName': 'Hoddesdon Town Football Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Hi Bar Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Chase Health and Fitness', 'BusinessTypeID': 1}
# {'BusinessName': 'Parklands Quendon Hall Events Venue', 'BusinessTypeID': 1}
# {'BusinessName': 'Quinntessential Catering', 'BusinessTypeID': 1}
# {'BusinessName': "Fill's Cafe", 'BusinessTypeID': 1}
# {'BusinessName': 'Wood Street Coffee Roasters Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Turpins Indoor Bowls Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Hope Community Hub-Make Lunch', 'BusinessTypeID': 1}
# {'BusinessName': 'Jam Hospitality Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'Lord Butler Leisure Centre', 'BusinessTypeID': 1}
# {'BusinessName': 'New Life Pentecostal Church', 'BusinessTypeID': 1}
# {'BusinessName': 'Radhuni Indian Cuisine', 'BusinessTypeID': 1}
# {'BusinessName': 'Maltings Cafe Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Deja Vu', 'BusinessTypeID': 1}
# {'BusinessName': 'Wrights Fish & Chips', 'BusinessTypeID': 1}
# {'BusinessName': 'SOKA Catering & Events Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Taste Of Raj', 'BusinessTypeID': 1}
# {'BusinessName': 'Saffron Walden Entertainments', 'BusinessTypeID': 1}
# {'BusinessName': "Fast Eddie's Community Cafe CIC (Fairycroft House)", 'BusinessTypeID': 1}
# {'BusinessName': 'Debden Grange Retirement Village', 'BusinessTypeID': 1}
# {'BusinessName': "Hopley's Cafe", 'BusinessTypeID': 1}
# {'BusinessName': "Libby's Coffee Shop", 'BusinessTypeID': 1}
# {'BusinessName': 'Monday Muscles', 'BusinessTypeID': 1}
# {'BusinessName': 'Khunnai Thai Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': "D'Art Waffle", 'BusinessTypeID': 1}
# {'BusinessName': "Kim's Tea And Coffee House", 'BusinessTypeID': 1}
# {'BusinessName': 'Bangkok Thai Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Dead Time Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'The Court Yard (Tiptree)', 'BusinessTypeID': 1}
# {'BusinessName': 'Starbucks Coffee', 'BusinessTypeID': 1}
# {'BusinessName': "EM's Coffee Bar", 'BusinessTypeID': 1}
# {'BusinessName': 'The Curiosity Fair', 'BusinessTypeID': 1}
# {'BusinessName': 'The Piano', 'BusinessTypeID': 1}
# {'BusinessName': 'The Saffron Suite', 'BusinessTypeID': 1}
# {'BusinessName': 'Bicicletta', 'BusinessTypeID': 1}
# {'BusinessName': 'Lokma (CK Saffron Ltd)', 'BusinessTypeID': 1}
# {'BusinessName': 'SW Baptist Church Lunch Club', 'BusinessTypeID': 1}
# {'BusinessName': 'Maze Cafe Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Pashas Grill', 'BusinessTypeID': 1}
# {'BusinessName': 'Indigo Indian Dining', 'BusinessTypeID': 1}
# {'BusinessName': 'Costa', 'BusinessTypeID': 1}
# {'BusinessName': 'Tea Amo', 'BusinessTypeID': 1}
# {'BusinessName': 'Dough & Co', 'BusinessTypeID': 1}
# {'BusinessName': 'The Curious Goat', 'BusinessTypeID': 1}
# {'BusinessName': 'La Boite Ltd.', 'BusinessTypeID': 1}
# {'BusinessName': 'Gluttons', 'BusinessTypeID': 1}
# {'BusinessName': 'Angela Reed Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Jade Garden', 'BusinessTypeID': 1}
# {'BusinessName': 'Support 4 Sight', 'BusinessTypeID': 1}
# {'BusinessName': 'Mocha Cafe', 'BusinessTypeID': 1}
# {'BusinessName': 'Cafe Cou Cou', 'BusinessTypeID': 1}
# {'BusinessName': 'Joseph Barnes Wines Limited', 'BusinessTypeID': 1}
# {'BusinessName': 'The Restaurant On Church Street', 'BusinessTypeID': 1}
# {'BusinessName': 'Chaters', 'BusinessTypeID': 1}
# {'BusinessName': 'St Marys C Of E Primary School', 'BusinessTypeID': 1}
# {'BusinessName': 'Saffron Hall Bar', 'BusinessTypeID': 1}
# {'BusinessName': 'St Marys Church', 'BusinessTypeID': 1}
# {'BusinessName': 'The Mogul Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Ananta', 'BusinessTypeID': 1}
# {'BusinessName': 'Audley End House \\& Restaurant', 'BusinessTypeID': 1}
# {'BusinessName': 'Wendens Ambo Pre School', 'BusinessTypeID': 1}
# {'BusinessName': 'The Cricketers', 'BusinessTypeID': 1}
# {'BusinessName': 'Clavering Village Hall', 'BusinessTypeID': 1}
# {'BusinessName': 'Audley End Miniature Railway Cafe & Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'China Garden', 'BusinessTypeID': 1}
# {'BusinessName': "Poppy's Tea Room", 'BusinessTypeID': 1}
# {'BusinessName': 'Brook Cottage Riding School', 'BusinessTypeID': 1}
# {'BusinessName': 'Something Lovely Ltd', 'BusinessTypeID': 1}
# {'BusinessName': 'Sliderman', 'BusinessTypeID': 1}
# {'BusinessName': 'Leapfrogs Pre-School', 'BusinessTypeID': 1}
# {'BusinessName': 'Old Swan Tea Shop', 'BusinessTypeID': 1}
# {'BusinessName': 'March Hare Tearoom', 'BusinessTypeID': 1}
# {'BusinessName': 'Tortoise Tea Room', 'BusinessTypeID': 1}
# {'BusinessName': 'The Barn At Alswick', 'BusinessTypeID': 1}
# {'BusinessName': 'Nuthampstead Shooting Ground', 'BusinessTypeID': 1}
# {'BusinessName': 'La Vita', 'BusinessTypeID': 1}
# {'BusinessName': 'Penang Flavours', 'BusinessTypeID': ''}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
penang_flavour_update = establishments.update_one({"BusinessName":"Penang Flavours"}, {"$set": {"BusinessTypeID": 1}})

# %%
# Confirm that the new restaurant was updated
penang_flavour_confirm = establishments.find_one({"BusinessName":"Penang Flavours"})
penang_flavour_confirm
# Out:
# {'_id': ObjectId('6574b84b4e3724f4b86a72b6'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count = establishments.count_documents({"LocalAuthorityName":"Dover"})
dover_count
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({"LocalAuthorityName":"Dover"})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
dover_find = establishments.find({"LocalAuthorityName":"Dover"})
dover_find
# Out:
# Not found

# %%
# Check that other documents remain with 'find_one'
dover_find_one = establishments.find_one({"LocalAuthorityName":"Dover"})
dover_find_one

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue

# %%
# Check that the coordinates and rating value are now numbers
